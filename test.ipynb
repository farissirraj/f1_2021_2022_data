# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
pit_stops = pd.read_csv('./archive/pit_stops.csv', index_col=False)
driver_standings = pd.read_csv('./archive/driver_standings.csv', index_col=False)
races = pd.read_csv('./archive/races.csv', index_col=False)

# %%
pit_stops = pit_stops.loc[pit_stops['raceId'] >= 1053]
pit_stops
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 8070    1053       839     1    1  15:05:16   30.866         30866
# 8071    1053        20     1    3  15:10:09   32.024         32024
# 8072    1053       854     1    5  15:15:11   51.007         51007
# 8073    1053       853     1   12  15:27:20   31.168         31168
# 8074    1053       842     1   14  15:30:10   31.068         31068
# ...      ...       ...   ...  ...       ...      ...           ...
# 9629    1096       849     2   38  18:02:50   25.174         25174
# 9630    1096       840     2   40  18:04:44   21.802         21802
# 9631    1096       839     2   41  18:06:09   21.734         21734
# 9632    1096       846     2   42  18:07:36   21.559         21559
# 9633    1096       855     2   44  18:11:10   23.159         23159
#
# [1533 rows x 7 columns]

# %%
drivers = pd.read_csv('./archive/drivers.csv', index_col=False)
driver_list = ['VER', 'PER', 'HAM', 'BOT', 'LEC', 'SAI', 'NOR', 'RIC', 'GAS', 'TSU', 'OCO', 'ALO', 'STR', 'VET', 'RAI', 'GIO', 'LAT', 'RUS', 'MSC', 'MAZ', 'MAG', 'ZHO']
drivers = drivers.loc[drivers['code'].isin(driver_list)]
driversDict = drivers.set_index('driverId').to_dict()['code']

drivers = drivers.drop([817], axis=0)
drivers = drivers.drop(['url', 'driverId', 'driverRef', 'forename', 'dob', 'nationality'], axis=1)
drivers = drivers.reindex(columns=['surname', 'code', 'number'])
drivers
# Out:
#         surname code number
# 0      Hamilton  HAM     44
# 3        Alonso  ALO     14
# 7     Räikkönen  RAI      7
# 19       Vettel  VET      5
# 29   Schumacher  MSC     \N
# 75    Magnussen  MAG     \N
# 452       Gasly  GAS     10
# 814       Pérez  PER     11
# 816   Ricciardo  RIC      3
# 821      Bottas  BOT     77
# 824   Magnussen  MAG     20
# 829  Verstappen  VER     33
# 831       Sainz  SAI     55
# 838        Ocon  OCO     31
# 839      Stroll  STR     18
# 840  Giovinazzi  GIO     99
# 842     Leclerc  LEC     16
# 844      Norris  NOR      4
# 845     Russell  RUS     63
# 847      Latifi  LAT      6
# 850     Tsunoda  TSU     22
# 851     Mazepin  MAZ      9
# 852  Schumacher  MSC     47
# 853        Zhou  ZHO     24

# %%
driver_standings
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33877              71821    1096       815   305.0         3            3
# 33878              71822    1096       830   454.0         1            1
# 33879              71823    1096       842    23.0        14           14
# 33880              71824    1096        20    37.0        12           12
# 33881              71825    1096       856     2.0        21           21
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
# Add First, Second, Third Place
races = races.loc[races['year'].isin([2021, 2022])]
races = races.drop(['url', 'fp1_time', 'fp2_time', 'fp3_time', 'quali_time', 'sprint_time'], axis=1)
races
# Out:
#       raceId  year  round  circuitId                       name        date  \
# 1035    1053  2021      2         21  Emilia Romagna Grand Prix  2021-04-18
# 1036    1074  2022      1          3         Bahrain Grand Prix  2022-03-20
# 1037    1052  2021      1          3         Bahrain Grand Prix  2021-03-28
# 1038    1051  2021     20         78           Qatar Grand Prix  2021-11-21
# 1039    1054  2021      3         75      Portuguese Grand Prix  2021-05-02
# 1040    1055  2021      4          4         Spanish Grand Prix  2021-05-09
# 1041    1056  2021      5          6          Monaco Grand Prix  2021-05-23
# 1042    1057  2021      6         73      Azerbaijan Grand Prix  2021-06-06
# 1043    1058  2021      8         70         Styrian Grand Prix  2021-06-27
# 1044    1059  2021      7         34          French Grand Prix  2021-06-20
# 1045    1060  2021      9         70        Austrian Grand Prix  2021-07-04
# ...

# %%
racesDict = races.set_index('raceId').to_dict()['circuitId']

# %%
pit_stops = pit_stops.loc[pit_stops['driverId'].isin(driversDict.keys())]
pit_stops
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 1        841        30     1    1  17:05:52   25.021         25021
# 3        841         4     1   12  17:22:34   23.251         23251
# 6        841        20     1   14  17:25:17   22.603         22603
# 11       841         1     1   16  17:28:24   23.227         23227
# 20       841        30     2   17  17:32:08   23.988         23988
# ...      ...       ...   ...  ...       ...      ...           ...
# 9629    1096       849     2   38  18:02:50   25.174         25174
# 9630    1096       840     2   40  18:04:44   21.802         21802
# 9631    1096       839     2   41  18:06:09   21.734         21734
# 9632    1096       846     2   42  18:07:36   21.559         21559
# 9633    1096       855     2   44  18:11:10   23.159         23159
#
# [5413 rows x 7 columns]
